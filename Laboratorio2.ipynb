# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresCarvajalWF/AnalisisDeDatos_CII2023/blob/main/Laboratorio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv = pd.read_csv("/content/spotify_top_music.csv")
csv

# %%
df = pd.DataFrame(csv)
df

# %%
ed_sheeran = df.loc[(df['artist']=='Ed Sheeran')]
ed_sheeran

# %%
ed_sheeran.year.plot.hist(grid=True, title="Cantidad de canciones de Ed Sheeran en el top 50 por año", sharex=True, sharey=True, facecolor=(.255, .100, .50), alpha=0.8)

plt.xlabel("Año")
plt.ylabel("Cant. Canciones")
plt.show()

# %%
top_by_genre = df.loc[(df['top genre']=='pop')]
top_by_genre

# %%
top_by_genre.year.plot.hist(grid=True, title="Cantidad de canciones de género 'pop' por año", sharex=True, sharey=True, facecolor=(.0, .255, .210), alpha=0.9)

plt.xlabel("Año")
plt.ylabel("Cant. Canciones")
plt.show()

# %%
songs_that_last_more_than_3_minutes = df.loc[(df['dur']<240)]
songs_that_last_more_than_3_minutes

# %%
songs_that_last_more_than_3_minutes.year.plot.hist(grid=True, title="Cantidad de canciones que duran más de 3 minutos", sharex=True, sharey=True, facecolor=(.150, .150, .150), alpha=0.9)

plt.xlabel("Año")
plt.ylabel("Cant. Canciones")
plt.show()
